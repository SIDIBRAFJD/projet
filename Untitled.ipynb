# %%
import ee, eemont, geemap
import pandas as pd
Map = geemap.Map()
geom = ee.FeatureCollection([ee.Feature(ee.Geometry.Polygon([[[-15.327075719833374,16.843462950466662],
  [-15.325809717178345,16.84301113290545],
  [-15.328245162963865,16.836870414568292],
  [-15.329457521438599,16.83734278458931]]]).buffer(40))])
s2 = ((ee.ImageCollection('COPERNICUS/S2_SR'))
      .filterDate('2020-07-01','2021-04-20')
      .filterBounds(geom)
      .maskClouds(method = 'qa')
      .maskClouds()
      .maskClouds(prob = 20)
      .maskClouds(buffer = 500)
      .maskClouds(dark = 0.1)
      .maskClouds(cloudDist = 2000)
      .maskClouds(cdi = -0.5)
      .maskClouds(maskShadows = False)
      .scale().maskClouds(scaledImage = True)
      .scaleAndOffset()
      .spectralIndices(['NDVI']))
ts = s2.getTimeSeriesByRegions(collection = geom,
                              bands = ['NDVI'],
                              reducer = [ee.Reducer.mean()],
                              scale = 30)
tsPandas = geemap.ee_to_pandas(ts)
tsPandas['date'] = pd.to_datetime(tsPandas['date'],infer_datetime_format = True)
tsPandas = pd.melt(tsPandas,
                   id_vars = ['reducer','date'],
                   value_vars = ['NDVI'],
                   var_name = 'Index',
                   value_name = 'Value')
tsPandas.dropna(subset=['Value'], how='all', inplace=True)
tsPandas
# Out:
#     reducer                date Index     Value
# 0      mean 2020-07-01 11:46:55  NDVI  0.058206
# 2      mean 2020-07-06 11:46:52  NDVI  0.052213
# 3      mean 2020-07-08 11:36:59  NDVI  0.053310
# 4      mean 2020-07-11 11:46:54  NDVI  0.049478
# 5      mean 2020-07-13 11:36:56  NDVI  0.064775
# ..      ...                 ...   ...       ...
# 112    mean 2021-04-09 11:36:52  NDVI  0.624652
# 113    mean 2021-04-12 11:46:46  NDVI  0.585881
# 114    mean 2021-04-14 11:36:49  NDVI  0.585001
# 115    mean 2021-04-17 11:46:44  NDVI  0.631203
# 116    mean 2021-04-19 11:36:50  NDVI  0.646459
#
# [87 rows x 4 columns]
